# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
import requests

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install JSON
# Out:
# ERROR: Could not find a version that satisfies the requirement JSON (from versions: none)
# ERROR: No matching distribution found for JSON
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pip
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
def data_season_list():
    url = "http://ergast.com/api/f1/seasons.json?limit=100"
    response = requests.get(url)
    if response.status_code == 200:x
        data = response.json()
        return pd.json_normalize(data['MRData']['SeasonTable']['Seasons'])
    return None

def data_race_schedule(season):
    url = f"http://ergast.com/api/f1/{season}.json"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        return pd.json_normalize(data['MRData']['RaceTable']['Races'])
    return None

def data_race_results(season, round_num):
    url = f"http://ergast.com/api/f1/{season}/{round_num}/results.json"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        return pd.json_normalize(data['MRData']['RaceTable']['Races'])
    return None

def data_qualifying_results(season, round_num):
    url = f"http://ergast.com/api/f1/{season}/{round_num}/qualifying.json"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        return pd.json_normalize(data['MRData']['RaceTable']['Races'])
    return None

def data_sprint_results(season, round_num):
    url = f"http://ergast.com/api/f1/{season}/{round_num}/sprint.json"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        return pd.json_normalize(data['MRData']['RaceTable']['Races'])
    return None

def data_driver_standings(season):
    url = f"http://ergast.com/api/f1/{season}/driverStandings.json"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        return pd.json_normalize(data['MRData']['StandingsTable']['StandingsLists'][0]['DriverStandings'])
    return None

def data_constructor_standings(season):
    url = f"http://ergast.com/api/f1/{season}/constructorStandings.json"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        return pd.json_normalize(data['MRData']['StandingsTable']['StandingsLists'][0]['ConstructorStandings'])
    return None

def data_driver_info():
    url = "http://ergast.com/api/f1/drivers.json?limit=1000"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        return pd.json_normalize(data['MRData']['DriverTable']['Drivers'])
    return None

def data_constructor_info():
    url = "http://ergast.com/api/f1/constructors.json?limit=1000"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        return pd.json_normalize(data['MRData']['ConstructorTable']['Constructors'])
    return None

def data_circuit_info():
    url = "http://ergast.com/api/f1/circuits.json?limit=1000"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        return pd.json_normalize(data['MRData']['CircuitTable']['Circuits'])
    return None

def data_status_info():
    url = "http://ergast.com/api/f1/status.json"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        return pd.json_normalize(data['MRData']['StatusTable']['Status'])
    return None

def data_lap_times(season, round_num, driver_id):
    url = f"http://ergast.com/api/f1/{season}/{round_num}/drivers/{driver_id}/laps.json?limit=2000"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        return pd.json_normalize(data['MRData']['RaceTable']['Races'][0]['Laps'])
    return None

def data_pit_stops(season, round_num, driver_id=None):
    url = f"http://ergast.com/api/f1/{season}/{round_num}/pitstops.json?limit=1000"
    if driver_id:
        url = f"http://ergast.com/api/f1/{season}/{round_num}/drivers/{driver_id}/pitstops.json?limit=1000"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        return pd.json_normalize(data['MRData']['RaceTable']['Races'][0]['PitStops'])
    return None

# %%
season = 2008
round_num = 12
driver_id = 'hamilton' 

qualifying_result_df = data_qualifying_results(season, round_num)
print(qualifying_result_df)
# Out:
#   season round                                                url  \
# 0   2008    12  http://en.wikipedia.org/wiki/2008_European_Gra...
#
#               raceName        date       time  \
# 0  European Grand Prix  2008-08-24  12:00:00Z
#
#                                    QualifyingResults Circuit.circuitId  \
# 0  [{'number': '2', 'position': '1', 'Driver': {'...          valencia
#
#                                          Circuit.url      Circuit.circuitName  \
# 0  http://en.wikipedia.org/wiki/Valencia_Street_C...  Valencia Street Circuit
#
#   Circuit.Location.lat Circuit.Location.long Circuit.Location.locality  \
# 0              39.4589             -0.331667                  Valencia
#
#   Circuit.Location.country
# 0                    Spain

# %%
def fetch_data(url):
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()
    return None

# %%
def save_season_list():
    url = "http://ergast.com/api/f1/seasons.json?limit=1000"
    data = fetch_data(url)
    if data:
        seasons = pd.json_normalize(data['MRData']['SeasonTable']['Seasons'])
        seasons.to_csv('season_list.csv', index=False)

# %%
save_season_list()

# %%
from time import sleep

def fetch_data(url):
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()
    return None

def save_season_list():
    url = "http://ergast.com/api/f1/seasons.json?limit=1000"
    data = fetch_data(url)
    if data:
        seasons = pd.json_normalize(data['MRData']['SeasonTable']['Seasons'])
        seasons.to_csv('season_list.csv', index=False)

def save_race_schedule():
    all_data = []
    for year in range(1950, 2024 + 1):
        url = f"http://ergast.com/api/f1/{year}.json"
        data = fetch_data(url)
        if data:
            races = pd.json_normalize(data['MRData']['RaceTable']['Races'])
            all_data.append(races)
        sleep(1)  # to respect API rate limit
    full_data = pd.concat(all_data, ignore_index=True)
    full_data.to_csv('race_schedule.csv', index=False)

def save_race_results():
    all_data = []
    for year in range(1950, 2024 + 1):
        url = f"http://ergast.com/api/f1/{year}/results.json?limit=1000"
        data = fetch_data(url)
        if data:
            results = pd.json_normalize(data['MRData']['RaceTable']['Races'])
            all_data.append(results)
        sleep(1)
    full_data = pd.concat(all_data, ignore_index=True)
    full_data.to_csv('race_results.csv', index=False)

def save_qualifying_results():
    all_data = []
    for year in range(1950, 2024 + 1):
        url = f"http://ergast.com/api/f1/{year}/qualifying.json?limit=1000"
        data = fetch_data(url)
        if data:
            qualifying = pd.json_normalize(data['MRData']['RaceTable']['Races'])
            all_data.append(qualifying)
        sleep(1)
    full_data = pd.concat(all_data, ignore_index=True)
    full_data.to_csv('qualifying_results.csv', index=False)

def save_sprint_results():
    all_data = []
    for year in range(2021, 2024 + 1):  
        url = f"http://ergast.com/api/f1/{year}/sprint.json"
        data = fetch_data(url)
        if data:
            sprints = pd.json_normalize(data['MRData']['RaceTable']['Races'])
            all_data.append(sprints)
        sleep(1)
    full_data = pd.concat(all_data, ignore_index=True)
    full_data.to_csv('sprint_results.csv', index=False)

def save_standings():
    all_data = []
    for year in range(1950, 2024 + 1):
        url = f"http://ergast.com/api/f1/{year}/driverStandings.json"
        data = fetch_data(url)
        if data:
            standings = pd.json_normalize(data['MRData']['StandingsTable']['StandingsLists'])
            all_data.append(standings)
        sleep(1)
    full_data = pd.concat(all_data, ignore_index=True)
    full_data.to_csv('driver_standings.csv', index=False)

def save_driver_info():
    url = "http://ergast.com/api/f1/drivers.json?limit=1000"
    data = fetch_data(url)
    if data:
        drivers = pd.json_normalize(data['MRData']['DriverTable']['Drivers'])
        drivers.to_csv('driver_info.csv', index=False)

def save_constructor_info():
    url = "http://ergast.com/api/f1/constructors.json?limit=1000"
    data = fetch_data(url)
    if data:
        constructors = pd.json_normalize(data['MRData']['ConstructorTable']['Constructors'])
        constructors.to_csv('constructor_info.csv', index=False)

def save_circuit_info():
    url = "http://ergast.com/api/f1/circuits.json?limit=1000"
    data = fetch_data(url)
    if data:
        circuits = pd.json_normalize(data['MRData']['CircuitTable']['Circuits'])
        circuits.to_csv('circuit_info.csv', index=False)

def save_finishing_status():
    url = "http://ergast.com/api/f1/status.json?limit=1000"
    data = fetch_data(url)
    if data:
        status = pd.json_normalize(data['MRData']['StatusTable']['Status'])
        status.to_csv('finishing_status.csv', index=False)

def save_lap_times():
    all_data = []
    for year in range(1996, 2024 + 1):  
        url = f"http://ergast.com/api/f1/{year}/laps.json?limit=1000"
        data = fetch_data(url)
        if data:
            laps = pd.json_normalize(data['MRData']['RaceTable']['Races'])
            all_data.append(laps)
        sleep(1)
    full_data = pd.concat(all_data, ignore_index=True)
    full_data.to_csv('lap_times.csv', index=False)

def save_pit_stops():
    all_data = []
    for year in range(2011, 2024 + 1):  
        url = f"http://ergast.com/api/f1/{year}/pitstops.json?limit=1000"
        data = fetch_data(url)
        if data:
            pitstops = pd.json_normalize(data['MRData']['RaceTable']['Races'])
            all_data.append(pitstops)
        sleep(1)
    full_data = pd.concat(all_data, ignore_index=True)
    full_data.to_csv('pit_stops.csv', index=False)

save_season_list()
save_race_schedule()
save_race_results()
save_qualifying_results()
save_sprint_results()
save_standings()
save_driver_info()
save_constructor_info()
save_circuit_info()
save_finishing_status()
save_lap_times()
save_pit_stops()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 129
#     126     full_data.to_csv('pit_stops.csv', index=False)
#     128 save_season_list()
# --> 129 save_race_schedule()
#     130 save_race_results()
#     131 save_qualifying_results()
#
# Cell In[16], line 24, in save_race_schedule()
#      22         races = pd.json_normalize(data['MRData']['RaceTable']['Races'])
#      23         all_data.append(races)
# ---> 24     sleep(1)  # to respect API rate limit
#      25 full_data = pd.concat(all_data, ignore_index=True)
#      26 full_data.to_csv('race_schedule.csv', index=False)
#
# KeyboardInterrupt:

# %%
from time import sleep 

def fetch_lap_times(season, round_num):
    url = f"http://ergast.com/api/f1/{season}/{round_num}/laps.json?limit=2000"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        laps = data['MRData']['RaceTable']['Races']
        if laps:  
            return pd.json_normalize(laps)
    return None  

def save_lap_times():
    all_data = []
    for season in range(2000, 2024 + 1):  
        for round_num in range(1, 22): 
            try:
                laps = fetch_lap_times(season, round_num)
                if laps is not None:
                    all_data.append(laps)
                    print(f"Added lap data for {season} round {round_num}")
                else:
                    print(f"No data for {season} round {round_num}")
                sleep(1)
            except Exception as e:
                print(f"Error fetching data for {season} round {round_num}: {e}")
    
    
    if all_data:
        full_data = pd.concat(all_data, ignore_index=True)
        full_data.to_csv('lap_times.csv', index=False)
        print("Lap times saved to lap_times.csv")
    else:
        print("No lap data available to save.")

save_lap_times()
# Out:
# Added lap data for 2000 round 1
# Added lap data for 2000 round 2
# Added lap data for 2000 round 3
# Added lap data for 2000 round 4
# Added lap data for 2000 round 5
# Added lap data for 2000 round 6
# Added lap data for 2000 round 7
# Added lap data for 2000 round 8
# Added lap data for 2000 round 9
# Added lap data for 2000 round 10
# Added lap data for 2000 round 11
# Added lap data for 2000 round 12
# Added lap data for 2000 round 13
# Added lap data for 2000 round 14
# Added lap data for 2000 round 15
# Added lap data for 2000 round 16
# Added lap data for 2000 round 17
# No data for 2000 round 18
# No data for 2000 round 19
# No data for 2000 round 20
# No data for 2000 round 21
# Added lap data for 2001 round 1
# Added lap data for 2001 round 2
# Added lap data for 2001 round 3
# Added lap data for 2001 round 4
# Added lap data for 2001 round 5
# Added lap data for 2001 round 6
# Added lap data for 2001 round 7
# Added lap data for 2001 round 8
# ...

# %%
def save_pit_stops():
    all_data = []
    for year in range(2011, 2024 + 1):  
        url = f"http://ergast.com/api/f1/{year}/pitstops.json?limit=1000"
        data = fetch_data(url)
        
        if data and 'Races' in data['MRData']['RaceTable']:
            pitstops = pd.json_normalize(data['MRData']['RaceTable']['Races'])
            if not pitstops.empty:  
                all_data.append(pitstops)
                print(f"Data for year {year} added.")
            else:
                print(f"No pit stop data for year {year}.")
        else:
            print(f"No data found for year {year}.")
        sleep(1)  
        
    if all_data:
        full_data = pd.concat(all_data, ignore_index=True)
        full_data.to_csv('pit_stops.csv', index=False)
        print("Pit stop data saved to pit_stops.csv")
    else:
        print("No pit stop data to save.")

save_pit_stops()
# Out:
# No data found for year 2011.
# No data found for year 2012.
# No data found for year 2013.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[45], line 25
#      22     else:
#      23         print("No pit stop data to save.")
# ---> 25 save_pit_stops()
#
# Cell In[45], line 5, in save_pit_stops()
#       3 for year in range(2011, 2024 + 1):
#       4     url = f"http://ergast.com/api/f1/{year}/pitstops.json?limit=1000"
# ----> 5     data = fetch_data(url)
#       7     if data and 'Races' in data['MRData']['RaceTable']:
#       8         pitstops = pd.json_normalize(data['MRData']['RaceTable']['Races'])
#
# Cell In[16], line 4, in fetch_data(url)
#       3 def fetch_data(url):
# ----> 4     response = requests.get(url)
#       5     if response.status_code == 200:
#       6         return response.json()
#
# ...

# %%
pip install fastf1
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import fastf1
import matplotlib.pyplot as plt
fastf1.Cache.enable_cache('/Users/rahulrajagopal/Documents/PBL - RaceWiz AI')
# !pip install --upgrade fastf1

# %%
# Driver performnance analysis (race data and stuff)
race_data = []

for year in range(2018, 2024):  
    for round_number in range(1, 24):  
        try:
            session = fastf1.get_session(year, round_number, 'R')  
            session.load()
            laps = session.laps[['Driver', 'LapNumber', 'LapTime', 'Compound', 'AirTemp', 'TrackTemp']]
            laps['Year'] = year
            laps['Round'] = round_number
            race_data.append(laps)
        except Exception as e:
            print(f"Failed to load data for {year} Round {round_number}: {e}")

laps_df = pd.concat(race_data, ignore_index=True)
print(laps_df.head())
# Out:
# logger      WARNING 	Failed to load schedule from FastF1 backend!
# req            INFO 	No cached data found for season_schedule. Loading data...
# _api           INFO 	Fetching season schedule...
# logger      WARNING 	Failed to load schedule from F1 API backend!
# logger      WARNING 	Failed to load schedule from Ergast API backend!
# Failed to load data for 2018 Round 1: Failed to load any schedule data.
# logger      WARNING 	Failed to load schedule from FastF1 backend!
# req            INFO 	No cached data found for season_schedule. Loading data...
# _api           INFO 	Fetching season schedule...
# logger      WARNING 	Failed to load schedule from F1 API backend!
# logger      WARNING 	Failed to load schedule from Ergast API backend!
# Failed to load data for 2018 Round 2: Failed to load any schedule data.
# logger      WARNING 	Failed to load schedule from FastF1 backend!
# req            INFO 	No cached data found for season_schedule. Loading data...
# ...

# %%
import pandas as pd
import fastf1
import matplotlib.pyplot as plt
from fastf1 import ergast

# %%
ergast = ergast(result_type='pandas', auto_cast=True)
race_schedule = ergast.get_race_results(season=2022)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 ergast = ergast(result_type='pandas', auto_cast=True)
#       2 race_schedule = ergast.get_race_results(season=2022, round=None, circuit=None, constructor=None, driver=None, grid_position=None, results_position=None, fastest_rank=None, status=None, result_type=None, auto_cast=None, limit=None, offset=None)
#
# TypeError: 'module' object is not callable
